# %%
#TASK 5: CHINESE SEGMENTATION USING JIEBA
# !pip install jieba
# Out:
# Requirement already satisfied: jieba in c:\users\gunes\anaconda3\lib\site-packages (0.42.1)

# %%
import jieba
seg = jieba.cut('把句子中所有的可以成词的词语都扫描出来', cut_all = True)
print(" ".join(seg))
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache C:\Users\gunes\AppData\Local\Temp\jieba.cache
# Loading model cost 2.584 seconds.
# Prefix dict has been built successfully.
# 把 句子 中所 所有 的 可以 成 词 的 词语 都 扫描 描出 描出来 出来

# %%
# TASK 1: BASIC TEXT PROCESSING PIPELINE
import nltk
texts = """A lot of groups, they get put together. But we don't even think of each other as a group. I don't think I'm in a group with two other guys, where I don't know their moms and their grandmas, their aunties, and I don't know where they came from. This is my immediate family. These are the only people I know. That's why we be around each other so much"""

for text in texts:
    sentences = nltk.sent_tokenize(texts)
    print(sentences)
    for sentence in sentences:
        words = nltk.word_tokenize(sentence)
        tagged = nltk.pos_tag(words)
        print(words)
        print(tagged)
# Out:
# ['A lot of groups, they get put together.', "But we don't even think of each other as a group.", "I don't think I'm in a group with two other guys, where I don't know their moms and their grandmas, their aunties, and I don't know where they came from.", 'This is my immediate family.', 'These are the only people I know.', "That's why we be around each other so much"]
# ['A', 'lot', 'of', 'groups', ',', 'they', 'get', 'put', 'together', '.']
# [('A', 'DT'), ('lot', 'NN'), ('of', 'IN'), ('groups', 'NNS'), (',', ','), ('they', 'PRP'), ('get', 'VBP'), ('put', 'VBN'), ('together', 'RB'), ('.', '.')]
# ['But', 'we', 'do', "n't", 'even', 'think', 'of', 'each', 'other', 'as', 'a', 'group', '.']
# [('But', 'CC'), ('we', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('even', 'RB'), ('think', 'VB'), ('of', 'IN'), ('each', 'DT'), ('other', 'JJ'), ('as', 'IN'), ('a', 'DT'), ('group', 'NN'), ('.', '.')]
# ['I', 'do', "n't", 'think', 'I', "'m", 'in', 'a', 'group', 'with', 'two', 'other', 'guys', ',', 'where', 'I', 'do', "n't", 'know', 'their', 'moms', 'and', 'their', 'grandmas', ',', 'their', 'aunties', ',', 'and', 'I', 'do', "n't", 'know', 'where', 'they', 'came', 'from', '.']
# [('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('think', 'VB'), ('I', 'PRP'), ("'m", 'VBP'), ('in', 'IN'), ('a', 'DT'), ('group', 'NN'), ('with', 'IN'), ('two', 'CD'), ('other', 'JJ'), ('guys', 'NNS'), (',', ','), ('where', 'WRB'), ('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('know', 'VB'), ('their', 'PRP$'), ('moms', 'NNS'), ('and', 'CC'), ('their', 'PRP$'), ('grandmas', 'NN'), (',', ','), ('their', 'PRP$'), ('aunties', 'NNS'), (',', ','), ('and', 'CC'), ('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('know', 'VB'), ('where', 'WRB'), ('they', 'PRP'), ('came', 'VBD'), ('from', 'IN'), ('.', '.')]
# ['This', 'is', 'my', 'immediate', 'family', '.']
# [('This', 'DT'), ('is', 'VBZ'), ('my', 'PRP$'), ('immediate', 'JJ'), ('family', 'NN'), ('.', '.')]
# ['These', 'are', 'the', 'only', 'people', 'I', 'know', '.']
# [('These', 'DT'), ('are', 'VBP'), ('the', 'DT'), ('only', 'JJ'), ('people', 'NNS'), ('I', 'PRP'), ('know', 'VBP'), ('.', '.')]
# ['That', "'s", 'why', 'we', 'be', 'around', 'each', 'other', 'so', 'much']
# [('That', 'DT'), ("'s", 'VBZ'), ('why', 'WRB'), ('we', 'PRP'), ('be', 'VB'), ('around', 'IN'), ('each', 'DT'), ('other', 'JJ'), ('so', 'RB'), ('much', 'JJ')]
# ['A lot of groups, they get put together.', "But we don't even think of each other as a group.", "I don't think I'm in a group with two other guys, where I don't know their moms and their grandmas, their aunties, and I don't know where they came from.", 'This is my immediate family.', 'These are the only people I know.', "That's why we be around each other so much"]
# ['A', 'lot', 'of', 'groups', ',', 'they', 'get', 'put', 'together', '.']
# [('A', 'DT'), ('lot', 'NN'), ('of', 'IN'), ('groups', 'NNS'), (',', ','), ('they', 'PRP'), ('get', 'VBP'), ('put', 'VBN'), ('together', 'RB'), ('.', '.')]
# ['But', 'we', 'do', "n't", 'even', 'think', 'of', 'each', 'other', 'as', 'a', 'group', '.']
# [('But', 'CC'), ('we', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('even', 'RB'), ('think', 'VB'), ('of', 'IN'), ('each', 'DT'), ('other', 'JJ'), ('as', 'IN'), ('a', 'DT'), ('group', 'NN'), ('.', '.')]
# ['I', 'do', "n't", 'think', 'I', "'m", 'in', 'a', 'group', 'with', 'two', 'other', 'guys', ',', 'where', 'I', 'do', "n't", 'know', 'their', 'moms', 'and', 'their', 'grandmas', ',', 'their', 'aunties', ',', 'and', 'I', 'do', "n't", 'know', 'where', 'they', 'came', 'from', '.']
# [('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('think', 'VB'), ('I', 'PRP'), ("'m", 'VBP'), ('in', 'IN'), ('a', 'DT'), ('group', 'NN'), ('with', 'IN'), ('two', 'CD'), ('other', 'JJ'), ('guys', 'NNS'), (',', ','), ('where', 'WRB'), ('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('know', 'VB'), ('their', 'PRP$'), ('moms', 'NNS'), ('and', 'CC'), ('their', 'PRP$'), ('grandmas', 'NN'), (',', ','), ('their', 'PRP$'), ('aunties', 'NNS'), (',', ','), ('and', 'CC'), ('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('know', 'VB'), ('where', 'WRB'), ('they', 'PRP'), ('came', 'VBD'), ('from', 'IN'), ('.', '.')]
# ['This', 'is', 'my', 'immediate', 'family', '.']
# [('This', 'DT'), ('is', 'VBZ'), ('my', 'PRP$'), ('immediate', 'JJ'), ('family', 'NN'), ('.', '.')]
# ['These', 'are', 'the', 'only', 'people', 'I', 'know', '.']
# [('These', 'DT'), ('are', 'VBP'), ('the', 'DT'), ('only', 'JJ'), ('people', 'NNS'), ('I', 'PRP'), ('know', 'VBP'), ('.', '.')]
# ['That', "'s", 'why', 'we', 'be', 'around', 'each', 'other', 'so', 'much']
# [('That', 'DT'), ("'s", 'VBZ'), ('why', 'WRB'), ('we', 'PRP'), ('be', 'VB'), ('around', 'IN'), ('each', 'DT'), ('other', 'JJ'), ('so', 'RB'), ('much', 'JJ')]
# ['A lot of groups, they get put together.', "But we don't even think of each other as a group.", "I don't think I'm in a group with two other guys, where I don't know their moms and their grandmas, their aunties, and I don't know where they came from.", 'This is my immediate family.', 'These are the only people I know.', "That's why we be around each other so much"]
# ['A', 'lot', 'of', 'groups', ',', 'they', 'get', 'put', 'together', '.']
# [('A', 'DT'), ('lot', 'NN'), ('of', 'IN'), ('groups', 'NNS'), (',', ','), ('they', 'PRP'), ('get', 'VBP'), ('put', 'VBN'), ('together', 'RB'), ('.', '.')]
# ['But', 'we', 'do', "n't", 'even', 'think', 'of', 'each', 'other', 'as', 'a', 'group', '.']
# [('But', 'CC'), ('we', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('even', 'RB'), ('think', 'VB'), ('of', 'IN'), ('each', 'DT'), ('other', 'JJ'), ('as', 'IN'), ('a', 'DT'), ('group', 'NN'), ('.', '.')]
# ['I', 'do', "n't", 'think', 'I', "'m", 'in', 'a', 'group', 'with', 'two', 'other', 'guys', ',', 'where', 'I', 'do', "n't", 'know', 'their', 'moms', 'and', 'their', 'grandmas', ',', 'their', 'aunties', ',', 'and', 'I', 'do', "n't", 'know', 'where', 'they', 'came', 'from', '.']
# [('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('think', 'VB'), ('I', 'PRP'), ("'m", 'VBP'), ('in', 'IN'), ('a', 'DT'), ('group', 'NN'), ('with', 'IN'), ('two', 'CD'), ('other', 'JJ'), ('guys', 'NNS'), (',', ','), ('where', 'WRB'), ('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('know', 'VB'), ('their', 'PRP$'), ('moms', 'NNS'), ('and', 'CC'), ('their', 'PRP$'), ('grandmas', 'NN'), (',', ','), ('their', 'PRP$'), ('aunties', 'NNS'), (',', ','), ('and', 'CC'), ('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('know', 'VB'), ('where', 'WRB'), ('they', 'PRP'), ('came', 'VBD'), ('from', 'IN'), ('.', '.')]
# ['This', 'is', 'my', 'immediate', 'family', '.']
# [('This', 'DT'), ('is', 'VBZ'), ('my', 'PRP$'), ('immediate', 'JJ'), ('family', 'NN'), ('.', '.')]
# ['These', 'are', 'the', 'only', 'people', 'I', 'know', '.']
# [('These', 'DT'), ('are', 'VBP'), ('the', 'DT'), ('only', 'JJ'), ('people', 'NNS'), ('I', 'PRP'), ('know', 'VBP'), ('.', '.')]
# ['That', "'s", 'why', 'we', 'be', 'around', 'each', 'other', 'so', 'much']
# [('That', 'DT'), ("'s", 'VBZ'), ('why', 'WRB'), ('we', 'PRP'), ('be', 'VB'), ('around', 'IN'), ('each', 'DT'), ('other', 'JJ'), ('so', 'RB'), ('much', 'JJ')]
# ['A lot of groups, they get put together.', "But we don't even think of each other as a group.", "I don't think I'm in a group with two other guys, where I don't know their moms and their grandmas, their aunties, and I don't know where they came from.", 'This is my immediate family.', 'These are the only people I know.', "That's why we be around each other so much"]
# ['A', 'lot', 'of', 'groups', ',', 'they', 'get', 'put', 'together', '.']
# [('A', 'DT'), ('lot', 'NN'), ('of', 'IN'), ('groups', 'NNS'), (',', ','), ('they', 'PRP'), ('get', 'VBP'), ('put', 'VBN'), ('together', 'RB'), ('.', '.')]
# ['But', 'we', 'do', "n't", 'even', 'think', 'of', 'each', 'other', 'as', 'a', 'group', '.']
# [('But', 'CC'), ('we', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('even', 'RB'), ('think', 'VB'), ('of', 'IN'), ('each', 'DT'), ('other', 'JJ'), ('as', 'IN'), ('a', 'DT'), ('group', 'NN'), ('.', '.')]
# ['I', 'do', "n't", 'think', 'I', "'m", 'in', 'a', 'group', 'with', 'two', 'other', 'guys', ',', 'where', 'I', 'do', "n't", 'know', 'their', 'moms', 'and', 'their', 'grandmas', ',', 'their', 'aunties', ',', 'and', 'I', 'do', "n't", 'know', 'where', 'they', 'came', 'from', '.']
# [('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('think', 'VB'), ('I', 'PRP'), ("'m", 'VBP'), ('in', 'IN'), ('a', 'DT'), ('group', 'NN'), ('with', 'IN'), ('two', 'CD'), ('other', 'JJ'), ('guys', 'NNS'), (',', ','), ('where', 'WRB'), ('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('know', 'VB'), ('their', 'PRP$'), ('moms', 'NNS'), ('and', 'CC'), ('their', 'PRP$'), ('grandmas', 'NN'), (',', ','), ('their', 'PRP$'), ('aunties', 'NNS'), (',', ','), ('and', 'CC'), ('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('know', 'VB'), ('where', 'WRB'), ('they', 'PRP'), ('came', 'VBD'), ('from', 'IN'), ('.', '.')]
# ['This', 'is', 'my', 'immediate', 'family', '.']
# [('This', 'DT'), ('is', 'VBZ'), ('my', 'PRP$'), ('immediate', 'JJ'), ('family', 'NN'), ('.', '.')]
# ['These', 'are', 'the', 'only', 'people', 'I', 'know', '.']
# [('These', 'DT'), ('are', 'VBP'), ('the', 'DT'), ('only', 'JJ'), ('people', 'NNS'), ('I', 'PRP'), ('know', 'VBP'), ('.', '.')]
# ['That', "'s", 'why', 'we', 'be', 'around', 'each', 'other', 'so', 'much']
# [('That', 'DT'), ("'s", 'VBZ'), ('why', 'WRB'), ('we', 'PRP'), ('be', 'VB'), ('around', 'IN'), ('each', 'DT'), ('other', 'JJ'), ('so', 'RB'), ('much', 'JJ')]
# ['A lot of groups, they get put together.', "But we don't even think of each other as a group.", "I don't think I'm in a group with two other guys, where I don't know their moms and their grandmas, their aunties, and I don't know where they came from.", 'This is my immediate family.', 'These are the only people I know.', "That's why we be around each other so much"]
# ['A', 'lot', 'of', 'groups', ',', 'they', 'get', 'put', 'together', '.']
# [('A', 'DT'), ('lot', 'NN'), ('of', 'IN'), ('groups', 'NNS'), (',', ','), ('they', 'PRP'), ('get', 'VBP'), ('put', 'VBN'), ('together', 'RB'), ('.', '.')]
# ['But', 'we', 'do', "n't", 'even', 'think', 'of', 'each', 'other', 'as', 'a', 'group', '.']
# [('But', 'CC'), ('we', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('even', 'RB'), ('think', 'VB'), ('of', 'IN'), ('each', 'DT'), ('other', 'JJ'), ('as', 'IN'), ('a', 'DT'), ('group', 'NN'), ('.', '.')]
# ['I', 'do', "n't", 'think', 'I', "'m", 'in', 'a', 'group', 'with', 'two', 'other', 'guys', ',', 'where', 'I', 'do', "n't", 'know', 'their', 'moms', 'and', 'their', 'grandmas', ',', 'their', 'aunties', ',', 'and', 'I', 'do', "n't", 'know', 'where', 'they', 'came', 'from', '.']
# [('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('think', 'VB'), ('I', 'PRP'), ("'m", 'VBP'), ('in', 'IN'), ('a', 'DT'), ('group', 'NN'), ('with', 'IN'), ('two', 'CD'), ('other', 'JJ'), ('guys', 'NNS'), (',', ','), ('where', 'WRB'), ('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('know', 'VB'), ('their', 'PRP$'), ('moms', 'NNS'), ('and', 'CC'), ('their', 'PRP$'), ('grandmas', 'NN'), (',', ','), ('their', 'PRP$'), ('aunties', 'NNS'), (',', ','), ('and', 'CC'), ('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('know', 'VB'), ('where', 'WRB'), ('they', 'PRP'), ('came', 'VBD'), ('from', 'IN'), ('.', '.')]
# ['This', 'is', 'my', 'immediate', 'family', '.']
# [('This', 'DT'), ('is', 'VBZ'), ('my', 'PRP$'), ('immediate', 'JJ'), ('family', 'NN'), ('.', '.')]
# ['These', 'are', 'the', 'only', 'people', 'I', 'know', '.']
# [('These', 'DT'), ('are', 'VBP'), ('the', 'DT'), ('only', 'JJ'), ('people', 'NNS'), ('I', 'PRP'), ('know', 'VBP'), ('.', '.')]
# ['That', "'s", 'why', 'we', 'be', 'around', 'each', 'other', 'so', 'much']
# [('That', 'DT'), ("'s", 'VBZ'), ('why', 'WRB'), ('we', 'PRP'), ('be', 'VB'), ('around', 'IN'), ('each', 'DT'), ('other', 'JJ'), ('so', 'RB'), ('much', 'JJ')]
# ['A lot of groups, they get put together.', "But we don't even think of each other as a group.", "I don't think I'm in a group with two other guys, where I don't know their moms and their grandmas, their aunties, and I don't know where they came from.", 'This is my immediate family.', 'These are the only people I know.', "That's why we be around each other so much"]
# ['A', 'lot', 'of', 'groups', ',', 'they', 'get', 'put', 'together', '.']
# [('A', 'DT'), ('lot', 'NN'), ('of', 'IN'), ('groups', 'NNS'), (',', ','), ('they', 'PRP'), ('get', 'VBP'), ('put', 'VBN'), ('together', 'RB'), ('.', '.')]
# ['But', 'we', 'do', "n't", 'even', 'think', 'of', 'each', 'other', 'as', 'a', 'group', '.']
# [('But', 'CC'), ('we', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('even', 'RB'), ('think', 'VB'), ('of', 'IN'), ('each', 'DT'), ('other', 'JJ'), ('as', 'IN'), ('a', 'DT'), ('group', 'NN'), ('.', '.')]
# ['I', 'do', "n't", 'think', 'I', "'m", 'in', 'a', 'group', 'with', 'two', 'other', 'guys', ',', 'where', 'I', 'do', "n't", 'know', 'their', 'moms', 'and', 'their', 'grandmas', ',', 'their', 'aunties', ',', 'and', 'I', 'do', "n't", 'know', 'where', 'they', 'came', 'from', '.']
# [('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('think', 'VB'), ('I', 'PRP'), ("'m", 'VBP'), ('in', 'IN'), ('a', 'DT'), ('group', 'NN'), ('with', 'IN'), ('two', 'CD'), ('other', 'JJ'), ('guys', 'NNS'), (',', ','), ('where', 'WRB'), ('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('know', 'VB'), ('their', 'PRP$'), ('moms', 'NNS'), ('and', 'CC'), ('their', 'PRP$'), ('grandmas', 'NN'), (',', ','), ('their', 'PRP$'), ('aunties', 'NNS'), (',', ','), ('and', 'CC'), ('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('know', 'VB'), ('where', 'WRB'), ('they', 'PRP'), ('came', 'VBD'), ('from', 'IN'), ('.', '.')]
# ['This', 'is', 'my', 'immediate', 'family', '.']
# [('This', 'DT'), ('is', 'VBZ'), ('my', 'PRP$'), ('immediate', 'JJ'), ('family', 'NN'), ('.', '.')]
# ['These', 'are', 'the', 'only', 'people', 'I', 'know', '.']
# [('These', 'DT'), ('are', 'VBP'), ('the', 'DT'), ('only', 'JJ'), ('people', 'NNS'), ('I', 'PRP'), ('know', 'VBP'), ('.', '.')]
# ['That', "'s", 'why', 'we', 'be', 'around', 'each', 'other', 'so', 'much']
# [('That', 'DT'), ("'s", 'VBZ'), ('why', 'WRB'), ('we', 'PRP'), ('be', 'VB'), ('around', 'IN'), ('each', 'DT'), ('other', 'JJ'), ('so', 'RB'), ('much', 'JJ')]
# ['A lot of groups, they get put together.', "But we don't even think of each other as a group.", "I don't think I'm in a group with two other guys, where I don't know their moms and their grandmas, their aunties, and I don't know where they came from.", 'This is my immediate family.', 'These are the only people I know.', "That's why we be around each other so much"]
# ['A', 'lot', 'of', 'groups', ',', 'they', 'get', 'put', 'together', '.']
# [('A', 'DT'), ('lot', 'NN'), ('of', 'IN'), ('groups', 'NNS'), (',', ','), ('they', 'PRP'), ('get', 'VBP'), ('put', 'VBN'), ('together', 'RB'), ('.', '.')]
# ['But', 'we', 'do', "n't", 'even', 'think', 'of', 'each', 'other', 'as', 'a', 'group', '.']
# [('But', 'CC'), ('we', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('even', 'RB'), ('think', 'VB'), ('of', 'IN'), ('each', 'DT'), ('other', 'JJ'), ('as', 'IN'), ('a', 'DT'), ('group', 'NN'), ('.', '.')]
# ['I', 'do', "n't", 'think', 'I', "'m", 'in', 'a', 'group', 'with', 'two', 'other', 'guys', ',', 'where', 'I', 'do', "n't", 'know', 'their', 'moms', 'and', 'their', 'grandmas', ',', 'their', 'aunties', ',', 'and', 'I', 'do', "n't", 'know', 'where', 'they', 'came', 'from', '.']
# [('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('think', 'VB'), ('I', 'PRP'), ("'m", 'VBP'), ('in', 'IN'), ('a', 'DT'), ('group', 'NN'), ('with', 'IN'), ('two', 'CD'), ('other', 'JJ'), ('guys', 'NNS'), (',', ','), ('where', 'WRB'), ('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('know', 'VB'), ('their', 'PRP$'), ('moms', 'NNS'), ('and', 'CC'), ('their', 'PRP$'), ('grandmas', 'NN'), (',', ','), ('their', 'PRP$'), ('aunties', 'NNS'), (',', ','), ('and', 'CC'), ('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('know', 'VB'), ('where', 'WRB'), ('they', 'PRP'), ('came', 'VBD'), ('from', 'IN'), ('.', '.')]
# ['This', 'is', 'my', 'immediate', 'family', '.']
# [('This', 'DT'), ('is', 'VBZ'), ('my', 'PRP$'), ('immediate', 'JJ'), ('family', 'NN'), ('.', '.')]
# ['These', 'are', 'the', 'only', 'people', 'I', 'know', '.']
# [('These', 'DT'), ('are', 'VBP'), ('the', 'DT'), ('only', 'JJ'), ('people', 'NNS'), ('I', 'PRP'), ('know', 'VBP'), ('.', '.')]
# ['That', "'s", 'why', 'we', 'be', 'around', 'each', 'other', 'so', 'much']
# [('That', 'DT'), ("'s", 'VBZ'), ('why', 'WRB'), ('we', 'PRP'), ('be', 'VB'), ('around', 'IN'), ('each', 'DT'), ('other', 'JJ'), ('so', 'RB'), ('much', 'JJ')]
# ['A lot of groups, they get put together.', "But we don't even think of each other as a group.", "I don't think I'm in a group with two other guys, where I don't know their moms and their grandmas, their aunties, and I don't know where they came from.", 'This is my immediate family.', 'These are the only people I know.', "That's why we be around each other so much"]
# ['A', 'lot', 'of', 'groups', ',', 'they', 'get', 'put', 'together', '.']
# [('A', 'DT'), ('lot', 'NN'), ('of', 'IN'), ('groups', 'NNS'), (',', ','), ('they', 'PRP'), ('get', 'VBP'), ('put', 'VBN'), ('together', 'RB'), ('.', '.')]
# ['But', 'we', 'do', "n't", 'even', 'think', 'of', 'each', 'other', 'as', 'a', 'group', '.']
# [('But', 'CC'), ('we', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('even', 'RB'), ('think', 'VB'), ('of', 'IN'), ('each', 'DT'), ('other', 'JJ'), ('as', 'IN'), ('a', 'DT'), ('group', 'NN'), ('.', '.')]
# ['I', 'do', "n't", 'think', 'I', "'m", 'in', 'a', 'group', 'with', 'two', 'other', 'guys', ',', 'where', 'I', 'do', "n't", 'know', 'their', 'moms', 'and', 'their', 'grandmas', ',', 'their', 'aunties', ',', 'and', 'I', 'do', "n't", 'know', 'where', 'they', 'came', 'from', '.']
# [('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('think', 'VB'), ('I', 'PRP'), ("'m", 'VBP'), ('in', 'IN'), ('a', 'DT'), ('group', 'NN'), ('with', 'IN'), ('two', 'CD'), ('other', 'JJ'), ('guys', 'NNS'), (',', ','), ('where', 'WRB'), ('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('know', 'VB'), ('their', 'PRP$'), ('moms', 'NNS'), ('and', 'CC'), ('their', 'PRP$'), ('grandmas', 'NN'), (',', ','), ('their', 'PRP$'), ('aunties', 'NNS'), (',', ','), ('and', 'CC'), ('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('know', 'VB'), ('where', 'WRB'), ('they', 'PRP'), ('came', 'VBD'), ('from', 'IN'), ('.', '.')]
# ['This', 'is', 'my', 'immediate', 'family', '.']
# [('This', 'DT'), ('is', 'VBZ'), ('my', 'PRP$'), ('immediate', 'JJ'), ('family', 'NN'), ('.', '.')]
# ['These', 'are', 'the', 'only', 'people', 'I', 'know', '.']
# [('These', 'DT'), ('are', 'VBP'), ('the', 'DT'), ('only', 'JJ'), ('people', 'NNS'), ('I', 'PRP'), ('know', 'VBP'), ('.', '.')]
# ['That', "'s", 'why', 'we', 'be', 'around', 'each', 'other', 'so', 'much']
# [('That', 'DT'), ("'s", 'VBZ'), ('why', 'WRB'), ('we', 'PRP'), ('be', 'VB'), ('around', 'IN'), ('each', 'DT'), ('other', 'JJ'), ('so', 'RB'), ('much', 'JJ')]
# ['A lot of groups, they get put together.', "But we don't even think of each other as a group.", "I don't think I'm in a group with two other guys, where I don't know their moms and their grandmas, their aunties, and I don't know where they came from.", 'This is my immediate family.', 'These are the only people I know.', "That's why we be around each other so much"]
# ['A', 'lot', 'of', 'groups', ',', 'they', 'get', 'put', 'together', '.']
# [('A', 'DT'), ('lot', 'NN'), ('of', 'IN'), ('groups', 'NNS'), (',', ','), ('they', 'PRP'), ('get', 'VBP'), ('put', 'VBN'), ('together', 'RB'), ('.', '.')]
# ['But', 'we', 'do', "n't", 'even', 'think', 'of', 'each', 'other', 'as', 'a', 'group', '.']
# [('But', 'CC'), ('we', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('even', 'RB'), ('think', 'VB'), ('of', 'IN'), ('each', 'DT'), ('other', 'JJ'), ('as', 'IN'), ('a', 'DT'), ('group', 'NN'), ('.', '.')]
# ['I', 'do', "n't", 'think', 'I', "'m", 'in', 'a', 'group', 'with', 'two', 'other', 'guys', ',', 'where', 'I', 'do', "n't", 'know', 'their', 'moms', 'and', 'their', 'grandmas', ',', 'their', 'aunties', ',', 'and', 'I', 'do', "n't", 'know', 'where', 'they', 'came', 'from', '.']
# [('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('think', 'VB'), ('I', 'PRP'), ("'m", 'VBP'), ('in', 'IN'), ('a', 'DT'), ('group', 'NN'), ('with', 'IN'), ('two', 'CD'), ('other', 'JJ'), ('guys', 'NNS'), (',', ','), ('where', 'WRB'), ('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('know', 'VB'), ('their', 'PRP$'), ('moms', 'NNS'), ('and', 'CC'), ('their', 'PRP$'), ('grandmas', 'NN'), (',', ','), ('their', 'PRP$'), ('aunties', 'NNS'), (',', ','), ('and', 'CC'), ('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('know', 'VB'), ('where', 'WRB'), ('they', 'PRP'), ('came', 'VBD'), ('from', 'IN'), ('.', '.')]
# ['This', 'is', 'my', 'immediate', 'family', '.']
# [('This', 'DT'), ('is', 'VBZ'), ('my', 'PRP$'), ('immediate', 'JJ'), ('family', 'NN'), ('.', '.')]
# ['These', 'are', 'the', 'only', 'people', 'I', 'know', '.']
# [('These', 'DT'), ('are', 'VBP'), ('the', 'DT'), ('only', 'JJ'), ('people', 'NNS'), ('I', 'PRP'), ('know', 'VBP'), ('.', '.')]
# ['That', "'s", 'why', 'we', 'be', 'around', 'each', 'other', 'so', 'much']
# [('That', 'DT'), ("'s", 'VBZ'), ('why', 'WRB'), ('we', 'PRP'), ('be', 'VB'), ('around', 'IN'), ('each', 'DT'), ('other', 'JJ'), ('so', 'RB'), ('much', 'JJ')]
# ['A lot of groups, they get put together.', "But we don't even think of each other as a group.", "I don't think I'm in a group with two other guys, where I don't know their moms and their grandmas, their aunties, and I don't know where they came from.", 'This is my immediate family.', 'These are the only people I know.', "That's why we be around each other so much"]
# ['A', 'lot', 'of', 'groups', ',', 'they', 'get', 'put', 'together', '.']
# [('A', 'DT'), ('lot', 'NN'), ('of', 'IN'), ('groups', 'NNS'), (',', ','), ('they', 'PRP'), ('get', 'VBP'), ('put', 'VBN'), ('together', 'RB'), ('.', '.')]
# ['But', 'we', 'do', "n't", 'even', 'think', 'of', 'each', 'other', 'as', 'a', 'group', '.']
# [('But', 'CC'), ('we', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('even', 'RB'), ('think', 'VB'), ('of', 'IN'), ('each', 'DT'), ('other', 'JJ'), ('as', 'IN'), ('a', 'DT'), ('group', 'NN'), ('.', '.')]
# ['I', 'do', "n't", 'think', 'I', "'m", 'in', 'a', 'group', 'with', 'two', 'other', 'guys', ',', 'where', 'I', 'do', "n't", 'know', 'their', 'moms', 'and', 'their', 'grandmas', ',', 'their', 'aunties', ',', 'and', 'I', 'do', "n't", 'know', 'where', 'they', 'came', 'from', '.']
# [('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('think', 'VB'), ('I', 'PRP'), ("'m", 'VBP'), ('in', 'IN'), ('a', 'DT'), ('group', 'NN'), ('with', 'IN'), ('two', 'CD'), ('other', 'JJ'), ('guys', 'NNS'), (',', ','), ('where', 'WRB'), ('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('know', 'VB'), ('their', 'PRP$'), ('moms', 'NNS'), ('and', 'CC'), ('their', 'PRP$'), ('grandmas', 'NN'), (',', ','), ('their', 'PRP$'), ('aunties', 'NNS'), (',', ','), ('and', 'CC'), ('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('know', 'VB'), ('where', 'WRB'), ('they', 'PRP'), ('came', 'VBD'), ('from', 'IN'), ('.', '.')]
# ['This', 'is', 'my', 'immediate', 'family', '.']
# [('This', 'DT'), ('is', 'VBZ'), ('my', 'PRP$'), ('immediate', 'JJ'), ('family', 'NN'), ('.', '.')]
# ['These', 'are', 'the', 'only', 'people', 'I', 'know', '.']
# [('These', 'DT'), ('are', 'VBP'), ('the', 'DT'), ('only', 'JJ'), ('people', 'NNS'), ('I', 'PRP'), ('know', 'VBP'), ('.', '.')]
# ['That', "'s", 'why', 'we', 'be', 'around', 'each', 'other', 'so', 'much']
# [('That', 'DT'), ("'s", 'VBZ'), ('why', 'WRB'), ('we', 'PRP'), ('be', 'VB'), ('around', 'IN'), ('each', 'DT'), ('other', 'JJ'), ('so', 'RB'), ('much', 'JJ')]
# ['A lot of groups, they get put together.', "But we don't even think of each other as a group.", "I don't think I'm in a group with two other guys, where I don't know their moms and their grandmas, their aunties, and I don't know where they came from.", 'This is my immediate family.', 'These are the only people I know.', "That's why we be around each other so much"]
# ['A', 'lot', 'of', 'groups', ',', 'they', 'get', 'put', 'together', '.']
# [('A', 'DT'), ('lot', 'NN'), ('of', 'IN'), ('groups', 'NNS'), (',', ','), ('they', 'PRP'), ('get', 'VBP'), ('put', 'VBN'), ('together', 'RB'), ('.', '.')]
# ['But', 'we', 'do', "n't", 'even', 'think', 'of', 'each', 'other', 'as', 'a', 'group', '.']
# [('But', 'CC'), ('we', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('even', 'RB'), ('think', 'VB'), ('of', 'IN'), ('each', 'DT'), ('other', 'JJ'), ('as', 'IN'), ('a', 'DT'), ('group', 'NN'), ('.', '.')]
# ['I', 'do', "n't", 'think', 'I', "'m", 'in', 'a', 'group', 'with', 'two', 'other', 'guys', ',', 'where', 'I', 'do', "n't", 'know', 'their', 'moms', 'and', 'their', 'grandmas', ',', 'their', 'aunties', ',', 'and', 'I', 'do', "n't", 'know', 'where', 'they', 'came', 'from', '.']
# [('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('think', 'VB'), ('I', 'PRP'), ("'m", 'VBP'), ('in', 'IN'), ('a', 'DT'), ('group', 'NN'), ('with', 'IN'), ('two', 'CD'), ('other', 'JJ'), ('guys', 'NNS'), (',', ','), ('where', 'WRB'), ('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('know', 'VB'), ('their', 'PRP$'), ('moms', 'NNS'), ('and', 'CC'), ('their', 'PRP$'), ('grandmas', 'NN'), (',', ','), ('their', 'PRP$'), ('aunties', 'NNS'), (',', ','), ('and', 'CC'), ('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('know', 'VB'), ('where', 'WRB'), ('they', 'PRP'), ('came', 'VBD'), ('from', 'IN'), ('.', '.')]
# ['This', 'is', 'my', 'immediate', 'family', '.']
# [('This', 'DT'), ('is', 'VBZ'), ('my', 'PRP$'), ('immediate', 'JJ'), ('family', 'NN'), ('.', '.')]
# ['These', 'are', 'the', 'only', 'people', 'I', 'know', '.']
# [('These', 'DT'), ('are', 'VBP'), ('the', 'DT'), ('only', 'JJ'), ('people', 'NNS'), ('I', 'PRP'), ('know', 'VBP'), ('.', '.')]
# ['That', "'s", 'why', 'we', 'be', 'around', 'each', 'other', 'so', 'much']
# [('That', 'DT'), ("'s", 'VBZ'), ('why', 'WRB'), ('we', 'PRP'), ('be', 'VB'), ('around', 'IN'), ('each', 'DT'), ('other', 'JJ'), ('so', 'RB'), ('much', 'JJ')]
# ['A lot of groups, they get put together.', "But we don't even think of each other as a group.", "I don't think I'm in a group with two other guys, where I don't know their moms and their grandmas, their aunties, and I don't know where they came from.", 'This is my immediate family.', 'These are the only people I know.', "That's why we be around each other so much"]
# ['A', 'lot', 'of', 'groups', ',', 'they', 'get', 'put', 'together', '.']
# [('A', 'DT'), ('lot', 'NN'), ('of', 'IN'), ('groups', 'NNS'), (',', ','), ('they', 'PRP'), ('get', 'VBP'), ('put', 'VBN'), ('together', 'RB'), ('.', '.')]
# ['But', 'we', 'do', "n't", 'even', 'think', 'of', 'each', 'other', 'as', 'a', 'group', '.']
# [('But', 'CC'), ('we', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('even', 'RB'), ('think', 'VB'), ('of', 'IN'), ('each', 'DT'), ('other', 'JJ'), ('as', 'IN'), ('a', 'DT'), ('group', 'NN'), ('.', '.')]
# ['I', 'do', "n't", 'think', 'I', "'m", 'in', 'a', 'group', 'with', 'two', 'other', 'guys', ',', 'where', 'I', 'do', "n't", 'know', 'their', 'moms', 'and', 'their', 'grandmas', ',', 'their', 'aunties', ',', 'and', 'I', 'do', "n't", 'know', 'where', 'they', 'came', 'from', '.']
# [('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('think', 'VB'), ('I', 'PRP'), ("'m", 'VBP'), ('in', 'IN'), ('a', 'DT'), ('group', 'NN'), ('with', 'IN'), ('two', 'CD'), ('other', 'JJ'), ('guys', 'NNS'), (',', ','), ('where', 'WRB'), ('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('know', 'VB'), ('their', 'PRP$'), ('moms', 'NNS'), ('and', 'CC'), ('their', 'PRP$'), ('grandmas', 'NN'), (',', ','), ('their', 'PRP$'), ('aunties', 'NNS'), (',', ','), ('and', 'CC'), ('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('know', 'VB'), ('where', 'WRB'), ('they', 'PRP'), ('came', 'VBD'), ('from', 'IN'), ('.', '.')]
# ['This', 'is', 'my', 'immediate', 'family', '.']
# [('This', 'DT'), ('is', 'VBZ'), ('my', 'PRP$'), ('immediate', 'JJ'), ('family', 'NN'), ('.', '.')]
# ['These', 'are', 'the', 'only', 'people', 'I', 'know', '.']
# [('These', 'DT'), ('are', 'VBP'), ('the', 'DT'), ('only', 'JJ'), ('people', 'NNS'), ('I', 'PRP'), ('know', 'VBP'), ('.', '.')]
# ['That', "'s", 'why', 'we', 'be', 'around', 'each', 'other', 'so', 'much']
# [('That', 'DT'), ("'s", 'VBZ'), ('why', 'WRB'), ('we', 'PRP'), ('be', 'VB'), ('around', 'IN'), ('each', 'DT'), ('other', 'JJ'), ('so', 'RB'), ('much', 'JJ')]
# ['A lot of groups, they get put together.', "But we don't even think of each other as a group.", "I don't think I'm in a group with two other guys, where I don't know their moms and their grandmas, their aunties, and I don't know where they came from.", 'This is my immediate family.', 'These are the only people I know.', "That's why we be around each other so much"]
# ['A', 'lot', 'of', 'groups', ',', 'they', 'get', 'put', 'together', '.']
# [('A', 'DT'), ('lot', 'NN'), ('of', 'IN'), ('groups', 'NNS'), (',', ','), ('they', 'PRP'), ('get', 'VBP'), ('put', 'VBN'), ('together', 'RB'), ('.', '.')]
# ['But', 'we', 'do', "n't", 'even', 'think', 'of', 'each', 'other', 'as', 'a', 'group', '.']
# [('But', 'CC'), ('we', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('even', 'RB'), ('think', 'VB'), ('of', 'IN'), ('each', 'DT'), ('other', 'JJ'), ('as', 'IN'), ('a', 'DT'), ('group', 'NN'), ('.', '.')]
# ['I', 'do', "n't", 'think', 'I', "'m", 'in', 'a', 'group', 'with', 'two', 'other', 'guys', ',', 'where', 'I', 'do', "n't", 'know', 'their', 'moms', 'and', 'their', 'grandmas', ',', 'their', 'aunties', ',', 'and', 'I', 'do', "n't", 'know', 'where', 'they', 'came', 'from', '.']
# [('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('think', 'VB'), ('I', 'PRP'), ("'m", 'VBP'), ('in', 'IN'), ('a', 'DT'), ('group', 'NN'), ('with', 'IN'), ('two', 'CD'), ('other', 'JJ'), ('guys', 'NNS'), (',', ','), ('where', 'WRB'), ('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('know', 'VB'), ('their', 'PRP$'), ('moms', 'NNS'), ('and', 'CC'), ('their', 'PRP$'), ('grandmas', 'NN'), (',', ','), ('their', 'PRP$'), ('aunties', 'NNS'), (',', ','), ('and', 'CC'), ('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('know', 'VB'), ('where', 'WRB'), ('they', 'PRP'), ('came', 'VBD'), ('from', 'IN'), ('.', '.')]
# ['This', 'is', 'my', 'immediate', 'family', '.']
# [('This', 'DT'), ('is', 'VBZ'), ('my', 'PRP$'), ('immediate', 'JJ'), ('family', 'NN'), ('.', '.')]
# ['These', 'are', 'the', 'only', 'people', 'I', 'know', '.']
# [('These', 'DT'), ('are', 'VBP'), ('the', 'DT'), ('only', 'JJ'), ('people', 'NNS'), ('I', 'PRP'), ('know', 'VBP'), ('.', '.')]
# ['That', "'s", 'why', 'we', 'be', 'around', 'each', 'other', 'so', 'much']
# [('That', 'DT'), ("'s", 'VBZ'), ('why', 'WRB'), ('we', 'PRP'), ('be', 'VB'), ('around', 'IN'), ('each', 'DT'), ('other', 'JJ'), ('so', 'RB'), ('much', 'JJ')]
# ['A lot of groups, they get put together.', "But we don't even think of each other as a group.", "I don't think I'm in a group with two other guys, where I don't know their moms and their grandmas, their aunties, and I don't know where they came from.", 'This is my immediate family.', 'These are the only people I know.', "That's why we be around each other so much"]
# ['A', 'lot', 'of', 'groups', ',', 'they', 'get', 'put', 'together', '.']
# [('A', 'DT'), ('lot', 'NN'), ('of', 'IN'), ('groups', 'NNS'), (',', ','), ('they', 'PRP'), ('get', 'VBP'), ('put', 'VBN'), ('together', 'RB'), ('.', '.')]
# ['But', 'we', 'do', "n't", 'even', 'think', 'of', 'each', 'other', 'as', 'a', 'group', '.']
# [('But', 'CC'), ('we', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('even', 'RB'), ('think', 'VB'), ('of', 'IN'), ('each', 'DT'), ('other', 'JJ'), ('as', 'IN'), ('a', 'DT'), ('group', 'NN'), ('.', '.')]
# ['I', 'do', "n't", 'think', 'I', "'m", 'in', 'a', 'group', 'with', 'two', 'other', 'guys', ',', 'where', 'I', 'do', "n't", 'know', 'their', 'moms', 'and', 'their', 'grandmas', ',', 'their', 'aunties', ',', 'and', 'I', 'do', "n't", 'know', 'where', 'they', 'came', 'from', '.']
# [('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('think', 'VB'), ('I', 'PRP'), ("'m", 'VBP'), ('in', 'IN'), ('a', 'DT'), ('group', 'NN'), ('with', 'IN'), ('two', 'CD'), ('other', 'JJ'), ('guys', 'NNS'), (',', ','), ('where', 'WRB'), ('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('know', 'VB'), ('their', 'PRP$'), ('moms', 'NNS'), ('and', 'CC'), ('their', 'PRP$'), ('grandmas', 'NN'), (',', ','), ('their', 'PRP$'), ('aunties', 'NNS'), (',', ','), ('and', 'CC'), ('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('know', 'VB'), ('where', 'WRB'), ('they', 'PRP'), ('came', 'VBD'), ('from', 'IN'), ('.', '.')]
# ['This', 'is', 'my', 'immediate', 'family', '.']
# [('This', 'DT'), ('is', 'VBZ'), ('my', 'PRP$'), ('immediate', 'JJ'), ('family', 'NN'), ('.', '.')]
# ['These', 'are', 'the', 'only', 'people', 'I', 'know', '.']
# [('These', 'DT'), ('are', 'VBP'), ('the', 'DT'), ('only', 'JJ'), ('people', 'NNS'), ('I', 'PRP'), ('know', 'VBP'), ('.', '.')]
# ['That', "'s", 'why', 'we', 'be', 'around', 'each', 'other', 'so', 'much']
# [('That', 'DT'), ("'s", 'VBZ'), ('why', 'WRB'), ('we', 'PRP'), ('be', 'VB'), ('around', 'IN'), ('each', 'DT'), ('other', 'JJ'), ('so', 'RB'), ('much', 'JJ')]
# ['A lot of groups, they get put together.', "But we don't even think of each other as a group.", "I don't think I'm in a group with two other guys, where I don't know their moms and their grandmas, their aunties, and I don't know where they came from.", 'This is my immediate family.', 'These are the only people I know.', "That's why we be around each other so much"]
# ['A', 'lot', 'of', 'groups', ',', 'they', 'get', 'put', 'together', '.']
# [('A', 'DT'), ('lot', 'NN'), ('of', 'IN'), ('groups', 'NNS'), (',', ','), ('they', 'PRP'), ('get', 'VBP'), ('put', 'VBN'), ('together', 'RB'), ('.', '.')]
# ['But', 'we', 'do', "n't", 'even', 'think', 'of', 'each', 'other', 'as', 'a', 'group', '.']
# [('But', 'CC'), ('we', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('even', 'RB'), ('think', 'VB'), ('of', 'IN'), ('each', 'DT'), ('other', 'JJ'), ('as', 'IN'), ('a', 'DT'), ('group', 'NN'), ('.', '.')]
# ['I', 'do', "n't", 'think', 'I', "'m", 'in', 'a', 'group', 'with', 'two', 'other', 'guys', ',', 'where', 'I', 'do', "n't", 'know', 'their', 'moms', 'and', 'their', 'grandmas', ',', 'their', 'aunties', ',', 'and', 'I', 'do', "n't", 'know', 'where', 'they', 'came', 'from', '.']
# [('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('think', 'VB'), ('I', 'PRP'), ("'m", 'VBP'), ('in', 'IN'), ('a', 'DT'), ('group', 'NN'), ('with', 'IN'), ('two', 'CD'), ('other', 'JJ'), ('guys', 'NNS'), (',', ','), ('where', 'WRB'), ('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('know', 'VB'), ('their', 'PRP$'), ('moms', 'NNS'), ('and', 'CC'), ('their', 'PRP$'), ('grandmas', 'NN'), (',', ','), ('their', 'PRP$'), ('aunties', 'NNS'), (',', ','), ('and', 'CC'), ('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('know', 'VB'), ('where', 'WRB'), ('they', 'PRP'), ('came', 'VBD'), ('from', 'IN'), ('.', '.')]
# ['This', 'is', 'my', 'immediate', 'family', '.']
# [('This', 'DT'), ('is', 'VBZ'), ('my', 'PRP$'), ('immediate', 'JJ'), ('family', 'NN'), ('.', '.')]
# ['These', 'are', 'the', 'only', 'people', 'I', 'know', '.']
# [('These', 'DT'), ('are', 'VBP'), ('the', 'DT'), ('only', 'JJ'), ('people', 'NNS'), ('I', 'PRP'), ('know', 'VBP'), ('.', '.')]
# ['That', "'s", 'why', 'we', 'be', 'around', 'each', 'other', 'so', 'much']
# [('That', 'DT'), ("'s", 'VBZ'), ('why', 'WRB'), ('we', 'PRP'), ('be', 'VB'), ('around', 'IN'), ('each', 'DT'), ('other', 'JJ'), ('so', 'RB'), ('much', 'JJ')]
# ['A lot of groups, they get put together.', "But we don't even think of each other as a group.", "I don't think I'm in a group with two other guys, where I don't know their moms and their grandmas, their aunties, and I don't know where they came from.", 'This is my immediate family.', 'These are the only people I know.', "That's why we be around each other so much"]
# ['A', 'lot', 'of', 'groups', ',', 'they', 'get', 'put', 'together', '.']
# [('A', 'DT'), ('lot', 'NN'), ('of', 'IN'), ('groups', 'NNS'), (',', ','), ('they', 'PRP'), ('get', 'VBP'), ('put', 'VBN'), ('together', 'RB'), ('.', '.')]
# ['But', 'we', 'do', "n't", 'even', 'think', 'of', 'each', 'other', 'as', 'a', 'group', '.']
# [('But', 'CC'), ('we', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('even', 'RB'), ('think', 'VB'), ('of', 'IN'), ('each', 'DT'), ('other', 'JJ'), ('as', 'IN'), ('a', 'DT'), ('group', 'NN'), ('.', '.')]
# ['I', 'do', "n't", 'think', 'I', "'m", 'in', 'a', 'group', 'with', 'two', 'other', 'guys', ',', 'where', 'I', 'do', "n't", 'know', 'their', 'moms', 'and', 'their', 'grandmas', ',', 'their', 'aunties', ',', 'and', 'I', 'do', "n't", 'know', 'where', 'they', 'came', 'from', '.']
# [('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('think', 'VB'), ('I', 'PRP'), ("'m", 'VBP'), ('in', 'IN'), ('a', 'DT'), ('group', 'NN'), ('with', 'IN'), ('two', 'CD'), ('other', 'JJ'), ('guys', 'NNS'), (',', ','), ('where', 'WRB'), ('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('know', 'VB'), ('their', 'PRP$'), ('moms', 'NNS'), ('and', 'CC'), ('their', 'PRP$'), ('grandmas', 'NN'), (',', ','), ('their', 'PRP$'), ('aunties', 'NNS'), (',', ','), ('and', 'CC'), ('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('know', 'VB'), ('where', 'WRB'), ('they', 'PRP'), ('came', 'VBD'), ('from', 'IN'), ('.', '.')]
# ['This', 'is', 'my', 'immediate', 'family', '.']
# [('This', 'DT'), ('is', 'VBZ'), ('my', 'PRP$'), ('immediate', 'JJ'), ('family', 'NN'), ('.', '.')]
# ['These', 'are', 'the', 'only', 'people', 'I', 'know', '.']
# [('These', 'DT'), ('are', 'VBP'), ('the', 'DT'), ('only', 'JJ'), ('people', 'NNS'), ('I', 'PRP'), ('know', 'VBP'), ('.', '.')]
# ['That', "'s", 'why', 'we', 'be', 'around', 'each', 'other', 'so', 'much']
# [('That', 'DT'), ("'s", 'VBZ'), ('why', 'WRB'), ('we', 'PRP'), ('be', 'VB'), ('around', 'IN'), ('each', 'DT'), ('other', 'JJ'), ('so', 'RB'), ('much', 'JJ')]
# ['A lot of groups, they get put together.', "But we don't even think of each other as a group.", "I don't think I'm in a group with two other guys, where I don't know their moms and their grandmas, their aunties, and I don't know where they came from.", 'This is my immediate family.', 'These are the only people I know.', "That's why we be around each other so much"]
# ['A', 'lot', 'of', 'groups', ',', 'they', 'get', 'put', 'together', '.']
# [('A', 'DT'), ('lot', 'NN'), ('of', 'IN'), ('groups', 'NNS'), (',', ','), ('they', 'PRP'), ('get', 'VBP'), ('put', 'VBN'), ('together', 'RB'), ('.', '.')]
# ['But', 'we', 'do', "n't", 'even', 'think', 'of', 'each', 'other', 'as', 'a', 'group', '.']
# [('But', 'CC'), ('we', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('even', 'RB'), ('think', 'VB'), ('of', 'IN'), ('each', 'DT'), ('other', 'JJ'), ('as', 'IN'), ('a', 'DT'), ('group', 'NN'), ('.', '.')]
# ['I', 'do', "n't", 'think', 'I', "'m", 'in', 'a', 'group', 'with', 'two', 'other', 'guys', ',', 'where', 'I', 'do', "n't", 'know', 'their', 'moms', 'and', 'their', 'grandmas', ',', 'their', 'aunties', ',', 'and', 'I', 'do', "n't", 'know', 'where', 'they', 'came', 'from', '.']
# [('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('think', 'VB'), ('I', 'PRP'), ("'m", 'VBP'), ('in', 'IN'), ('a', 'DT'), ('group', 'NN'), ('with', 'IN'), ('two', 'CD'), ('other', 'JJ'), ('guys', 'NNS'), (',', ','), ('where', 'WRB'), ('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('know', 'VB'), ('their', 'PRP$'), ('moms', 'NNS'), ('and', 'CC'), ('their', 'PRP$'), ('grandmas', 'NN'), (',', ','), ('their', 'PRP$'), ('aunties', 'NNS'), (',', ','), ('and', 'CC'), ('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('know', 'VB'), ('where', 'WRB'), ('they', 'PRP'), ('came', 'VBD'), ('from', 'IN'), ('.', '.')]
# ['This', 'is', 'my', 'immediate', 'family', '.']
# [('This', 'DT'), ('is', 'VBZ'), ('my', 'PRP$'), ('immediate', 'JJ'), ('family', 'NN'), ('.', '.')]
# ['These', 'are', 'the', 'only', 'people', 'I', 'know', '.']
# [('These', 'DT'), ('are', 'VBP'), ('the', 'DT'), ('only', 'JJ'), ('people', 'NNS'), ('I', 'PRP'), ('know', 'VBP'), ('.', '.')]
# ['That', "'s", 'why', 'we', 'be', 'around', 'each', 'other', 'so', 'much']
# [('That', 'DT'), ("'s", 'VBZ'), ('why', 'WRB'), ('we', 'PRP'), ('be', 'VB'), ('around', 'IN'), ('each', 'DT'), ('other', 'JJ'), ('so', 'RB'), ('much', 'JJ')]
# ['A lot of groups, they get put together.', "But we don't even think of each other as a group.", "I don't think I'm in a group with two other guys, where I don't know their moms and their grandmas, their aunties, and I don't know where they came from.", 'This is my immediate family.', 'These are the only people I know.', "That's why we be around each other so much"]
# ['A', 'lot', 'of', 'groups', ',', 'they', 'get', 'put', 'together', '.']
# [('A', 'DT'), ('lot', 'NN'), ('of', 'IN'), ('groups', 'NNS'), (',', ','), ('they', 'PRP'), ('get', 'VBP'), ('put', 'VBN'), ('together', 'RB'), ('.', '.')]
# ['But', 'we', 'do', "n't", 'even', 'think', 'of', 'each', 'other', 'as', 'a', 'group', '.']
# [('But', 'CC'), ('we', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('even', 'RB'), ('think', 'VB'), ('of', 'IN'), ('each', 'DT'), ('other', 'JJ'), ('as', 'IN'), ('a', 'DT'), ('group', 'NN'), ('.', '.')]
# ['I', 'do', "n't", 'think', 'I', "'m", 'in', 'a', 'group', 'with', 'two', 'other', 'guys', ',', 'where', 'I', 'do', "n't", 'know', 'their', 'moms', 'and', 'their', 'grandmas', ',', 'their', 'aunties', ',', 'and', 'I', 'do', "n't", 'know', 'where', 'they', 'came', 'from', '.']
# [('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('think', 'VB'), ('I', 'PRP'), ("'m", 'VBP'), ('in', 'IN'), ('a', 'DT'), ('group', 'NN'), ('with', 'IN'), ('two', 'CD'), ('other', 'JJ'), ('guys', 'NNS'), (',', ','), ('where', 'WRB'), ('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('know', 'VB'), ('their', 'PRP$'), ('moms', 'NNS'), ('and', 'CC'), ('their', 'PRP$'), ('grandmas', 'NN'), (',', ','), ('their', 'PRP$'), ('aunties', 'NNS'), (',', ','), ('and', 'CC'), ('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('know', 'VB'), ('where', 'WRB'), ('they', 'PRP'), ('came', 'VBD'), ('from', 'IN'), ('.', '.')]
# ['This', 'is', 'my', 'immediate', 'family', '.']
# [('This', 'DT'), ('is', 'VBZ'), ('my', 'PRP$'), ('immediate', 'JJ'), ('family', 'NN'), ('.', '.')]
# ['These', 'are', 'the', 'only', 'people', 'I', 'know', '.']
# [('These', 'DT'), ('are', 'VBP'), ('the', 'DT'), ('only', 'JJ'), ('people', 'NNS'), ('I', 'PRP'), ('know', 'VBP'), ('.', '.')]
# ['That', "'s", 'why', 'we', 'be', 'around', 'each', 'other', 'so', 'much']
# [('That', 'DT'), ("'s", 'VBZ'), ('why', 'WRB'), ('we', 'PRP'), ('be', 'VB'), ('around', 'IN'), ('each', 'DT'), ('other', 'JJ'), ('so', 'RB'), ('much', 'JJ')]
# ['A lot of groups, they get put together.', "But we don't even think of each other as a group.", "I don't think I'm in a group with two other guys, where I don't know their moms and their grandmas, their aunties, and I don't know where they came from.", 'This is my immediate family.', 'These are the only people I know.', "That's why we be around each other so much"]
# ['A', 'lot', 'of', 'groups', ',', 'they', 'get', 'put', 'together', '.']
# [('A', 'DT'), ('lot', 'NN'), ('of', 'IN'), ('groups', 'NNS'), (',', ','), ('they', 'PRP'), ('get', 'VBP'), ('put', 'VBN'), ('together', 'RB'), ('.', '.')]
# ['But', 'we', 'do', "n't", 'even', 'think', 'of', 'each', 'other', 'as', 'a', 'group', '.']
# [('But', 'CC'), ('we', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('even', 'RB'), ('think', 'VB'), ('of', 'IN'), ('each', 'DT'), ('other', 'JJ'), ('as', 'IN'), ('a', 'DT'), ('group', 'NN'), ('.', '.')]
# ['I', 'do', "n't", 'think', 'I', "'m", 'in', 'a', 'group', 'with', 'two', 'other', 'guys', ',', 'where', 'I', 'do', "n't", 'know', 'their', 'moms', 'and', 'their', 'grandmas', ',', 'their', 'aunties', ',', 'and', 'I', 'do', "n't", 'know', 'where', 'they', 'came', 'from', '.']
# [('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('think', 'VB'), ('I', 'PRP'), ("'m", 'VBP'), ('in', 'IN'), ('a', 'DT'), ('group', 'NN'), ('with', 'IN'), ('two', 'CD'), ('other', 'JJ'), ('guys', 'NNS'), (',', ','), ('where', 'WRB'), ('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('know', 'VB'), ('their', 'PRP$'), ('moms', 'NNS'), ('and', 'CC'), ('their', 'PRP$'), ('grandmas', 'NN'), (',', ','), ('their', 'PRP$'), ('aunties', 'NNS'), (',', ','), ('and', 'CC'), ('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('know', 'VB'), ('where', 'WRB'), ('they', 'PRP'), ('came', 'VBD'), ('from', 'IN'), ('.', '.')]
# ['This', 'is', 'my', 'immediate', 'family', '.']
# [('This', 'DT'), ('is', 'VBZ'), ('my', 'PRP$'), ('immediate', 'JJ'), ('family', 'NN'), ('.', '.')]
# ['These', 'are', 'the', 'only', 'people', 'I', 'know', '.']
# [('These', 'DT'), ('are', 'VBP'), ('the', 'DT'), ('only', 'JJ'), ('people', 'NNS'), ('I', 'PRP'), ('know', 'VBP'), ('.', '.')]
# ['That', "'s", 'why', 'we', 'be', 'around', 'each', 'other', 'so', 'much']
# [('That', 'DT'), ("'s", 'VBZ'), ('why', 'WRB'), ('we', 'PRP'), ('be', 'VB'), ('around', 'IN'), ('each', 'DT'), ('other', 'JJ'), ('so', 'RB'), ('much', 'JJ')]
# ['A lot of groups, they get put together.', "But we don't even think of each other as a group.", "I don't think I'm in a group with two other guys, where I don't know their moms and their grandmas, their aunties, and I don't know where they came from.", 'This is my immediate family.', 'These are the only people I know.', "That's why we be around each other so much"]
# ['A', 'lot', 'of', 'groups', ',', 'they', 'get', 'put', 'together', '.']
# [('A', 'DT'), ('lot', 'NN'), ('of', 'IN'), ('groups', 'NNS'), (',', ','), ('they', 'PRP'), ('get', 'VBP'), ('put', 'VBN'), ('together', 'RB'), ('.', '.')]
# ['But', 'we', 'do', "n't", 'even', 'think', 'of', 'each', 'other', 'as', 'a', 'group', '.']
# [('But', 'CC'), ('we', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('even', 'RB'), ('think', 'VB'), ('of', 'IN'), ('each', 'DT'), ('other', 'JJ'), ('as', 'IN'), ('a', 'DT'), ('group', 'NN'), ('.', '.')]
# ['I', 'do', "n't", 'think', 'I', "'m", 'in', 'a', 'group', 'with', 'two', 'other', 'guys', ',', 'where', 'I', 'do', "n't", 'know', 'their', 'moms', 'and', 'their', 'grandmas', ',', 'their', 'aunties', ',', 'and', 'I', 'do', "n't", 'know', 'where', 'they', 'came', 'from', '.']
# [('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('think', 'VB'), ('I', 'PRP'), ("'m", 'VBP'), ('in', 'IN'), ('a', 'DT'), ('group', 'NN'), ('with', 'IN'), ('two', 'CD'), ('other', 'JJ'), ('guys', 'NNS'), (',', ','), ('where', 'WRB'), ('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('know', 'VB'), ('their', 'PRP$'), ('moms', 'NNS'), ('and', 'CC'), ('their', 'PRP$'), ('grandmas', 'NN'), (',', ','), ('their', 'PRP$'), ('aunties', 'NNS'), (',', ','), ('and', 'CC'), ('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('know', 'VB'), ('where', 'WRB'), ('they', 'PRP'), ('came', 'VBD'), ('from', 'IN'), ('.', '.')]
# ['This', 'is', 'my', 'immediate', 'family', '.']
# [('This', 'DT'), ('is', 'VBZ'), ('my', 'PRP$'), ('immediate', 'JJ'), ('family', 'NN'), ('.', '.')]
# ['These', 'are', 'the', 'only', 'people', 'I', 'know', '.']
# [('These', 'DT'), ('are', 'VBP'), ('the', 'DT'), ('only', 'JJ'), ('people', 'NNS'), ('I', 'PRP'), ('know', 'VBP'), ('.', '.')]
# ['That', "'s", 'why', 'we', 'be', 'around', 'each', 'other', 'so', 'much']
# [('That', 'DT'), ("'s", 'VBZ'), ('why', 'WRB'), ('we', 'PRP'), ('be', 'VB'), ('around', 'IN'), ('each', 'DT'), ('other', 'JJ'), ('so', 'RB'), ('much', 'JJ')]
# ['A lot of groups, they get put together.', "But we don't even think of each other as a group.", "I don't think I'm in a group with two other guys, where I don't know their moms and their grandmas, their aunties, and I don't know where they came from.", 'This is my immediate family.', 'These are the only people I know.', "That's why we be around each other so much"]
# ['A', 'lot', 'of', 'groups', ',', 'they', 'get', 'put', 'together', '.']
# [('A', 'DT'), ('lot', 'NN'), ('of', 'IN'), ('groups', 'NNS'), (',', ','), ('they', 'PRP'), ('get', 'VBP'), ('put', 'VBN'), ('together', 'RB'), ('.', '.')]
# ['But', 'we', 'do', "n't", 'even', 'think', 'of', 'each', 'other', 'as', 'a', 'group', '.']
# [('But', 'CC'), ('we', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('even', 'RB'), ('think', 'VB'), ('of', 'IN'), ('each', 'DT'), ('other', 'JJ'), ('as', 'IN'), ('a', 'DT'), ('group', 'NN'), ('.', '.')]
# ['I', 'do', "n't", 'think', 'I', "'m", 'in', 'a', 'group', 'with', 'two', 'other', 'guys', ',', 'where', 'I', 'do', "n't", 'know', 'their', 'moms', 'and', 'their', 'grandmas', ',', 'their', 'aunties', ',', 'and', 'I', 'do', "n't", 'know', 'where', 'they', 'came', 'from', '.']
# ...
# ['A', 'lot', 'of', 'groups', ',', 'they', 'get', 'put', 'together', '.']
# [('A', 'DT'), ('lot', 'NN'), ('of', 'IN'), ('groups', 'NNS'), (',', ','), ('they', 'PRP'), ('get', 'VBP'), ('put', 'VBN'), ('together', 'RB'), ('.', '.')]
# ['But', 'we', 'do', "n't", 'even', 'think', 'of', 'each', 'other', 'as', 'a', 'group', '.']
# [('But', 'CC'), ('we', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('even', 'RB'), ('think', 'VB'), ('of', 'IN'), ('each', 'DT'), ('other', 'JJ'), ('as', 'IN'), ('a', 'DT'), ('group', 'NN'), ('.', '.')]
# ['I', 'do', "n't", 'think', 'I', "'m", 'in', 'a', 'group', 'with', 'two', 'other', 'guys', ',', 'where', 'I', 'do', "n't", 'know', 'their', 'moms', 'and', 'their', 'grandmas', ',', 'their', 'aunties', ',', 'and', 'I', 'do', "n't", 'know', 'where', 'they', 'came', 'from', '.']
# [('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('think', 'VB'), ('I', 'PRP'), ("'m", 'VBP'), ('in', 'IN'), ('a', 'DT'), ('group', 'NN'), ('with', 'IN'), ('two', 'CD'), ('other', 'JJ'), ('guys', 'NNS'), (',', ','), ('where', 'WRB'), ('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('know', 'VB'), ('their', 'PRP$'), ('moms', 'NNS'), ('and', 'CC'), ('their', 'PRP$'), ('grandmas', 'NN'), (',', ','), ('their', 'PRP$'), ('aunties', 'NNS'), (',', ','), ('and', 'CC'), ('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('know', 'VB'), ('where', 'WRB'), ('they', 'PRP'), ('came', 'VBD'), ('from', 'IN'), ('.', '.')]
# ['This', 'is', 'my', 'immediate', 'family', '.']
# [('This', 'DT'), ('is', 'VBZ'), ('my', 'PRP$'), ('immediate', 'JJ'), ('family', 'NN'), ('.', '.')]
# ['These', 'are', 'the', 'only', 'people', 'I', 'know', '.']
# [('These', 'DT'), ('are', 'VBP'), ('the', 'DT'), ('only', 'JJ'), ('people', 'NNS'), ('I', 'PRP'), ('know', 'VBP'), ('.', '.')]
# ['That', "'s", 'why', 'we', 'be', 'around', 'each', 'other', 'so', 'much']
# [('That', 'DT'), ("'s", 'VBZ'), ('why', 'WRB'), ('we', 'PRP'), ('be', 'VB'), ('around', 'IN'), ('each', 'DT'), ('other', 'JJ'), ('so', 'RB'), ('much', 'JJ')]
# ['A lot of groups, they get put together.', "But we don't even think of each other as a group.", "I don't think I'm in a group with two other guys, where I don't know their moms and their grandmas, their aunties, and I don't know where they came from.", 'This is my immediate family.', 'These are the only people I know.', "That's why we be around each other so much"]
# ['A', 'lot', 'of', 'groups', ',', 'they', 'get', 'put', 'together', '.']
# [('A', 'DT'), ('lot', 'NN'), ('of', 'IN'), ('groups', 'NNS'), (',', ','), ('they', 'PRP'), ('get', 'VBP'), ('put', 'VBN'), ('together', 'RB'), ('.', '.')]
# ['But', 'we', 'do', "n't", 'even', 'think', 'of', 'each', 'other', 'as', 'a', 'group', '.']
# [('But', 'CC'), ('we', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('even', 'RB'), ('think', 'VB'), ('of', 'IN'), ('each', 'DT'), ('other', 'JJ'), ('as', 'IN'), ('a', 'DT'), ('group', 'NN'), ('.', '.')]
# ['I', 'do', "n't", 'think', 'I', "'m", 'in', 'a', 'group', 'with', 'two', 'other', 'guys', ',', 'where', 'I', 'do', "n't", 'know', 'their', 'moms', 'and', 'their', 'grandmas', ',', 'their', 'aunties', ',', 'and', 'I', 'do', "n't", 'know', 'where', 'they', 'came', 'from', '.']
# [('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('think', 'VB'), ('I', 'PRP'), ("'m", 'VBP'), ('in', 'IN'), ('a', 'DT'), ('group', 'NN'), ('with', 'IN'), ('two', 'CD'), ('other', 'JJ'), ('guys', 'NNS'), (',', ','), ('where', 'WRB'), ('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('know', 'VB'), ('their', 'PRP$'), ('moms', 'NNS'), ('and', 'CC'), ('their', 'PRP$'), ('grandmas', 'NN'), (',', ','), ('their', 'PRP$'), ('aunties', 'NNS'), (',', ','), ('and', 'CC'), ('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('know', 'VB'), ('where', 'WRB'), ('they', 'PRP'), ('came', 'VBD'), ('from', 'IN'), ('.', '.')]
# ['This', 'is', 'my', 'immediate', 'family', '.']
# [('This', 'DT'), ('is', 'VBZ'), ('my', 'PRP$'), ('immediate', 'JJ'), ('family', 'NN'), ('.', '.')]
# ['These', 'are', 'the', 'only', 'people', 'I', 'know', '.']
# [('These', 'DT'), ('are', 'VBP'), ('the', 'DT'), ('only', 'JJ'), ('people', 'NNS'), ('I', 'PRP'), ('know', 'VBP'), ('.', '.')]
# ['That', "'s", 'why', 'we', 'be', 'around', 'each', 'other', 'so', 'much']
# [('That', 'DT'), ("'s", 'VBZ'), ('why', 'WRB'), ('we', 'PRP'), ('be', 'VB'), ('around', 'IN'), ('each', 'DT'), ('other', 'JJ'), ('so', 'RB'), ('much', 'JJ')]
# ['A lot of groups, they get put together.', "But we don't even think of each other as a group.", "I don't think I'm in a group with two other guys, where I don't know their moms and their grandmas, their aunties, and I don't know where they came from.", 'This is my immediate family.', 'These are the only people I know.', "That's why we be around each other so much"]
# ['A', 'lot', 'of', 'groups', ',', 'they', 'get', 'put', 'together', '.']
# [('A', 'DT'), ('lot', 'NN'), ('of', 'IN'), ('groups', 'NNS'), (',', ','), ('they', 'PRP'), ('get', 'VBP'), ('put', 'VBN'), ('together', 'RB'), ('.', '.')]
# ['But', 'we', 'do', "n't", 'even', 'think', 'of', 'each', 'other', 'as', 'a', 'group', '.']
# [('But', 'CC'), ('we', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('even', 'RB'), ('think', 'VB'), ('of', 'IN'), ('each', 'DT'), ('other', 'JJ'), ('as', 'IN'), ('a', 'DT'), ('group', 'NN'), ('.', '.')]
# ['I', 'do', "n't", 'think', 'I', "'m", 'in', 'a', 'group', 'with', 'two', 'other', 'guys', ',', 'where', 'I', 'do', "n't", 'know', 'their', 'moms', 'and', 'their', 'grandmas', ',', 'their', 'aunties', ',', 'and', 'I', 'do', "n't", 'know', 'where', 'they', 'came', 'from', '.']
# [('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('think', 'VB'), ('I', 'PRP'), ("'m", 'VBP'), ('in', 'IN'), ('a', 'DT'), ('group', 'NN'), ('with', 'IN'), ('two', 'CD'), ('other', 'JJ'), ('guys', 'NNS'), (',', ','), ('where', 'WRB'), ('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('know', 'VB'), ('their', 'PRP$'), ('moms', 'NNS'), ('and', 'CC'), ('their', 'PRP$'), ('grandmas', 'NN'), (',', ','), ('their', 'PRP$'), ('aunties', 'NNS'), (',', ','), ('and', 'CC'), ('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('know', 'VB'), ('where', 'WRB'), ('they', 'PRP'), ('came', 'VBD'), ('from', 'IN'), ('.', '.')]
# ['This', 'is', 'my', 'immediate', 'family', '.']
# [('This', 'DT'), ('is', 'VBZ'), ('my', 'PRP$'), ('immediate', 'JJ'), ('family', 'NN'), ('.', '.')]
# ['These', 'are', 'the', 'only', 'people', 'I', 'know', '.']
# [('These', 'DT'), ('are', 'VBP'), ('the', 'DT'), ('only', 'JJ'), ('people', 'NNS'), ('I', 'PRP'), ('know', 'VBP'), ('.', '.')]
# ['That', "'s", 'why', 'we', 'be', 'around', 'each', 'other', 'so', 'much']
# [('That', 'DT'), ("'s", 'VBZ'), ('why', 'WRB'), ('we', 'PRP'), ('be', 'VB'), ('around', 'IN'), ('each', 'DT'), ('other', 'JJ'), ('so', 'RB'), ('much', 'JJ')]
# ['A lot of groups, they get put together.', "But we don't even think of each other as a group.", "I don't think I'm in a group with two other guys, where I don't know their moms and their grandmas, their aunties, and I don't know where they came from.", 'This is my immediate family.', 'These are the only people I know.', "That's why we be around each other so much"]
# ['A', 'lot', 'of', 'groups', ',', 'they', 'get', 'put', 'together', '.']
# [('A', 'DT'), ('lot', 'NN'), ('of', 'IN'), ('groups', 'NNS'), (',', ','), ('they', 'PRP'), ('get', 'VBP'), ('put', 'VBN'), ('together', 'RB'), ('.', '.')]
# ['But', 'we', 'do', "n't", 'even', 'think', 'of', 'each', 'other', 'as', 'a', 'group', '.']
# [('But', 'CC'), ('we', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('even', 'RB'), ('think', 'VB'), ('of', 'IN'), ('each', 'DT'), ('other', 'JJ'), ('as', 'IN'), ('a', 'DT'), ('group', 'NN'), ('.', '.')]
# ['I', 'do', "n't", 'think', 'I', "'m", 'in', 'a', 'group', 'with', 'two', 'other', 'guys', ',', 'where', 'I', 'do', "n't", 'know', 'their', 'moms', 'and', 'their', 'grandmas', ',', 'their', 'aunties', ',', 'and', 'I', 'do', "n't", 'know', 'where', 'they', 'came', 'from', '.']
# [('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('think', 'VB'), ('I', 'PRP'), ("'m", 'VBP'), ('in', 'IN'), ('a', 'DT'), ('group', 'NN'), ('with', 'IN'), ('two', 'CD'), ('other', 'JJ'), ('guys', 'NNS'), (',', ','), ('where', 'WRB'), ('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('know', 'VB'), ('their', 'PRP$'), ('moms', 'NNS'), ('and', 'CC'), ('their', 'PRP$'), ('grandmas', 'NN'), (',', ','), ('their', 'PRP$'), ('aunties', 'NNS'), (',', ','), ('and', 'CC'), ('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('know', 'VB'), ('where', 'WRB'), ('they', 'PRP'), ('came', 'VBD'), ('from', 'IN'), ('.', '.')]
# ['This', 'is', 'my', 'immediate', 'family', '.']
# [('This', 'DT'), ('is', 'VBZ'), ('my', 'PRP$'), ('immediate', 'JJ'), ('family', 'NN'), ('.', '.')]
# ['These', 'are', 'the', 'only', 'people', 'I', 'know', '.']
# [('These', 'DT'), ('are', 'VBP'), ('the', 'DT'), ('only', 'JJ'), ('people', 'NNS'), ('I', 'PRP'), ('know', 'VBP'), ('.', '.')]
# ['That', "'s", 'why', 'we', 'be', 'around', 'each', 'other', 'so', 'much']
# [('That', 'DT'), ("'s", 'VBZ'), ('why', 'WRB'), ('we', 'PRP'), ('be', 'VB'), ('around', 'IN'), ('each', 'DT'), ('other', 'JJ'), ('so', 'RB'), ('much', 'JJ')]
# ['A lot of groups, they get put together.', "But we don't even think of each other as a group.", "I don't think I'm in a group with two other guys, where I don't know their moms and their grandmas, their aunties, and I don't know where they came from.", 'This is my immediate family.', 'These are the only people I know.', "That's why we be around each other so much"]
# ['A', 'lot', 'of', 'groups', ',', 'they', 'get', 'put', 'together', '.']
# [('A', 'DT'), ('lot', 'NN'), ('of', 'IN'), ('groups', 'NNS'), (',', ','), ('they', 'PRP'), ('get', 'VBP'), ('put', 'VBN'), ('together', 'RB'), ('.', '.')]
# ['But', 'we', 'do', "n't", 'even', 'think', 'of', 'each', 'other', 'as', 'a', 'group', '.']
# [('But', 'CC'), ('we', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('even', 'RB'), ('think', 'VB'), ('of', 'IN'), ('each', 'DT'), ('other', 'JJ'), ('as', 'IN'), ('a', 'DT'), ('group', 'NN'), ('.', '.')]
# ['I', 'do', "n't", 'think', 'I', "'m", 'in', 'a', 'group', 'with', 'two', 'other', 'guys', ',', 'where', 'I', 'do', "n't", 'know', 'their', 'moms', 'and', 'their', 'grandmas', ',', 'their', 'aunties', ',', 'and', 'I', 'do', "n't", 'know', 'where', 'they', 'came', 'from', '.']
# [('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('think', 'VB'), ('I', 'PRP'), ("'m", 'VBP'), ('in', 'IN'), ('a', 'DT'), ('group', 'NN'), ('with', 'IN'), ('two', 'CD'), ('other', 'JJ'), ('guys', 'NNS'), (',', ','), ('where', 'WRB'), ('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('know', 'VB'), ('their', 'PRP$'), ('moms', 'NNS'), ('and', 'CC'), ('their', 'PRP$'), ('grandmas', 'NN'), (',', ','), ('their', 'PRP$'), ('aunties', 'NNS'), (',', ','), ('and', 'CC'), ('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('know', 'VB'), ('where', 'WRB'), ('they', 'PRP'), ('came', 'VBD'), ('from', 'IN'), ('.', '.')]
# ['This', 'is', 'my', 'immediate', 'family', '.']
# [('This', 'DT'), ('is', 'VBZ'), ('my', 'PRP$'), ('immediate', 'JJ'), ('family', 'NN'), ('.', '.')]
# ['These', 'are', 'the', 'only', 'people', 'I', 'know', '.']
# [('These', 'DT'), ('are', 'VBP'), ('the', 'DT'), ('only', 'JJ'), ('people', 'NNS'), ('I', 'PRP'), ('know', 'VBP'), ('.', '.')]
# ['That', "'s", 'why', 'we', 'be', 'around', 'each', 'other', 'so', 'much']
# [('That', 'DT'), ("'s", 'VBZ'), ('why', 'WRB'), ('we', 'PRP'), ('be', 'VB'), ('around', 'IN'), ('each', 'DT'), ('other', 'JJ'), ('so', 'RB'), ('much', 'JJ')]
# ['A lot of groups, they get put together.', "But we don't even think of each other as a group.", "I don't think I'm in a group with two other guys, where I don't know their moms and their grandmas, their aunties, and I don't know where they came from.", 'This is my immediate family.', 'These are the only people I know.', "That's why we be around each other so much"]
# ['A', 'lot', 'of', 'groups', ',', 'they', 'get', 'put', 'together', '.']
# [('A', 'DT'), ('lot', 'NN'), ('of', 'IN'), ('groups', 'NNS'), (',', ','), ('they', 'PRP'), ('get', 'VBP'), ('put', 'VBN'), ('together', 'RB'), ('.', '.')]
# ['But', 'we', 'do', "n't", 'even', 'think', 'of', 'each', 'other', 'as', 'a', 'group', '.']
# [('But', 'CC'), ('we', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('even', 'RB'), ('think', 'VB'), ('of', 'IN'), ('each', 'DT'), ('other', 'JJ'), ('as', 'IN'), ('a', 'DT'), ('group', 'NN'), ('.', '.')]
# ['I', 'do', "n't", 'think', 'I', "'m", 'in', 'a', 'group', 'with', 'two', 'other', 'guys', ',', 'where', 'I', 'do', "n't", 'know', 'their', 'moms', 'and', 'their', 'grandmas', ',', 'their', 'aunties', ',', 'and', 'I', 'do', "n't", 'know', 'where', 'they', 'came', 'from', '.']
# [('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('think', 'VB'), ('I', 'PRP'), ("'m", 'VBP'), ('in', 'IN'), ('a', 'DT'), ('group', 'NN'), ('with', 'IN'), ('two', 'CD'), ('other', 'JJ'), ('guys', 'NNS'), (',', ','), ('where', 'WRB'), ('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('know', 'VB'), ('their', 'PRP$'), ('moms', 'NNS'), ('and', 'CC'), ('their', 'PRP$'), ('grandmas', 'NN'), (',', ','), ('their', 'PRP$'), ('aunties', 'NNS'), (',', ','), ('and', 'CC'), ('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('know', 'VB'), ('where', 'WRB'), ('they', 'PRP'), ('came', 'VBD'), ('from', 'IN'), ('.', '.')]
# ['This', 'is', 'my', 'immediate', 'family', '.']
# [('This', 'DT'), ('is', 'VBZ'), ('my', 'PRP$'), ('immediate', 'JJ'), ('family', 'NN'), ('.', '.')]
# ['These', 'are', 'the', 'only', 'people', 'I', 'know', '.']
# [('These', 'DT'), ('are', 'VBP'), ('the', 'DT'), ('only', 'JJ'), ('people', 'NNS'), ('I', 'PRP'), ('know', 'VBP'), ('.', '.')]
# ['That', "'s", 'why', 'we', 'be', 'around', 'each', 'other', 'so', 'much']
# [('That', 'DT'), ("'s", 'VBZ'), ('why', 'WRB'), ('we', 'PRP'), ('be', 'VB'), ('around', 'IN'), ('each', 'DT'), ('other', 'JJ'), ('so', 'RB'), ('much', 'JJ')]
# ['A lot of groups, they get put together.', "But we don't even think of each other as a group.", "I don't think I'm in a group with two other guys, where I don't know their moms and their grandmas, their aunties, and I don't know where they came from.", 'This is my immediate family.', 'These are the only people I know.', "That's why we be around each other so much"]
# ['A', 'lot', 'of', 'groups', ',', 'they', 'get', 'put', 'together', '.']
# [('A', 'DT'), ('lot', 'NN'), ('of', 'IN'), ('groups', 'NNS'), (',', ','), ('they', 'PRP'), ('get', 'VBP'), ('put', 'VBN'), ('together', 'RB'), ('.', '.')]
# ['But', 'we', 'do', "n't", 'even', 'think', 'of', 'each', 'other', 'as', 'a', 'group', '.']
# [('But', 'CC'), ('we', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('even', 'RB'), ('think', 'VB'), ('of', 'IN'), ('each', 'DT'), ('other', 'JJ'), ('as', 'IN'), ('a', 'DT'), ('group', 'NN'), ('.', '.')]
# ['I', 'do', "n't", 'think', 'I', "'m", 'in', 'a', 'group', 'with', 'two', 'other', 'guys', ',', 'where', 'I', 'do', "n't", 'know', 'their', 'moms', 'and', 'their', 'grandmas', ',', 'their', 'aunties', ',', 'and', 'I', 'do', "n't", 'know', 'where', 'they', 'came', 'from', '.']
# [('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('think', 'VB'), ('I', 'PRP'), ("'m", 'VBP'), ('in', 'IN'), ('a', 'DT'), ('group', 'NN'), ('with', 'IN'), ('two', 'CD'), ('other', 'JJ'), ('guys', 'NNS'), (',', ','), ('where', 'WRB'), ('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('know', 'VB'), ('their', 'PRP$'), ('moms', 'NNS'), ('and', 'CC'), ('their', 'PRP$'), ('grandmas', 'NN'), (',', ','), ('their', 'PRP$'), ('aunties', 'NNS'), (',', ','), ('and', 'CC'), ('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('know', 'VB'), ('where', 'WRB'), ('they', 'PRP'), ('came', 'VBD'), ('from', 'IN'), ('.', '.')]
# ['This', 'is', 'my', 'immediate', 'family', '.']
# [('This', 'DT'), ('is', 'VBZ'), ('my', 'PRP$'), ('immediate', 'JJ'), ('family', 'NN'), ('.', '.')]
# ['These', 'are', 'the', 'only', 'people', 'I', 'know', '.']
# [('These', 'DT'), ('are', 'VBP'), ('the', 'DT'), ('only', 'JJ'), ('people', 'NNS'), ('I', 'PRP'), ('know', 'VBP'), ('.', '.')]
# ['That', "'s", 'why', 'we', 'be', 'around', 'each', 'other', 'so', 'much']
# [('That', 'DT'), ("'s", 'VBZ'), ('why', 'WRB'), ('we', 'PRP'), ('be', 'VB'), ('around', 'IN'), ('each', 'DT'), ('other', 'JJ'), ('so', 'RB'), ('much', 'JJ')]

# %%
#TASK 2: Tweet Tokeniser
import nltk
from nltk.tokenize import TweetTokenizer
text = 'The party is lit!'
twtkn = TweetTokenizer()
twtkn.tokenize(text)
# Out:
# ['The', 'party', 'is', 'lit', '!']

# %%
#TASK 3: SCRAPING DATA FROM WEB
from urllib import request
url = "http://www.gutenberg.org/files/2554/2554-0.txt"
response = request.urlopen(url)
raw = response.read().decode('utf8')
from nltk.tokenize import word_tokenize
tokens = word_tokenize(raw)
text = nltk.Text(tokens)
text[:50]
#HTML -> ASCII -> TOKEN -> TEXT -> VOCAB
# Out:
# ['\ufeffThe',
#  'Project',
#  'Gutenberg',
#  'EBook',
#  'of',
#  'Crime',
#  'and',
#  'Punishment',
#  ',',
#  'by',
#  'Fyodor',
#  'Dostoevsky',
#  'This',
#  'eBook',
#  'is',
#  'for',
#  'the',
#  'use',
#  'of',
#  'anyone',
#  'anywhere',
#  'at',
#  'no',
#  'cost',
#  'and',
#  'with',
#  'almost',
#  'no',
#  'restrictions',
#  'whatsoever',
#  '.',
#  'You',
#  'may',
#  'copy',
#  'it',
#  ',',
#  'give',
#  'it',
#  'away',
#  'or',
#  're-use',
#  'it',
#  'under',
#  'the',
#  'terms',
#  'of',
#  'the',
#  'Project',
#  'Gutenberg',
#  'License']

# %%
type(tokens)
# Out:
# list
